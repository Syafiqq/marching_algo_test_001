# %%
import numpy as np
import pyvista as pv
import marching_3d_rules_minimal as rules

# %%
points = np.array(
    [
        [10, 10, 10],
        [20, 10, 10],
        [10, 20, 10],
        [20, 20, 10],
        [10, 10, 20],
        [20, 10, 20],
        [10, 20, 20],
        [20, 20, 20],
    ]
    , dtype=np.float)
points
# Out:
# array([[10., 10., 10.],
#        [20., 10., 10.],
#        [10., 20., 10.],
#        [20., 20., 10.],
#        [10., 10., 20.],
#        [20., 10., 20.],
#        [10., 20., 20.],
#        [20., 20., 20.]])

# %%
def plot_data(cloud_points, faces):
    cloud = pv.PolyData(cloud_points, faces=faces)
    plot = pv.Plotter()
    plot.add_points(points)
    plot.add_mesh(cloud, show_edges=True, edge_color='r')
    plot.show_bounds()
    plot.show_grid()
    plot.camera_position = 'yz'
    plot.camera.azimuth = -45.0
    plot.camera.elevation = 30.0
    plot.show()

# %%
# Rule 126
# point_type == 0b01001110:
# 0 1 0 0   1 1 1 0
#
#   o     7
# o     o
#   2     3
# 0     o
#
rule_type = 0b10110100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# /Users/engineering/Documents/anaconda3/envs/shapely-pyvista/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F210EA8D0>

# %%
# Rule 127
# 0 0 1 0   1 1 1 0
#
#   o     7
# o     o
#   o     3
# 0     1
#
rule_type = 0b00101110
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F21471588>

# %%
# Rule 128
# 0 0 0 1   1 1 1 0
#
#   o     7
# o     o
#   2     o
# 0     1
#
rule_type = 0b00011110
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F21471A90>

# %%
# Rule 129
# 1 1 1 0   0 0 0 1
#
#   6     o
# 4     5
#   o     3
# o     o
#
rule_type = 0b11100001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F4A128>

# %%
# Rule 130
# 1 1 0 1   0 0 0 1
#
#   6     o
# 4     5
#   2     o
# o     o
#
rule_type = 0b11010001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F506D8>

# %%
# Rule 131
# 1 0 1 1   0 0 0 1
#
#   6     o
# 4     5
#   o     o
# o     1
#
rule_type = 0b10110001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F210CAAC8>

# %%
# Rule 132
# 0 1 1 1   0 0 0 1
#
#   6     o
# 4     5
#   o     o
# 0     o
#
rule_type = 0b01110001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F214714A8>

# %%
# Rule 133
# 0 0 0 0   0 0 0 0
#
#   6     o
# o     5
#   2     3
# o     o
#
rule_type = 0b11001001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F50438>

# %%
# Rule 134
# 1 0 1 0   1 0 0 1
#
#   6     o
# o     5
#   o     3
# o     1
#
rule_type = 0b10101001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F50AC8>

# %%
# Rule 135
# 0 1 1 0   1 0 0 1
#
#   6     o
# o     5
#   o     3
# 0     o
#
rule_type = 0b01101001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F62198>

# %%
# Rule 136
# 1 0 0 1   1 0 0 1
#
#   6     o
# o     5
#   2     o
# o     1
#
rule_type = 0b10011001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F210CA9B0>

# %%
# Rule 137
# 0 1 0 1   1 0 0 1
#
#   6     o
# o     5
#   2     o
# 0     o
#
rule_type = 0b01011001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F624E0>

# %%
# Rule 138
# 0 0 1 1   1 0 0 1
#
#   6     o
# o     5
#   o     o
# 0     1
#
rule_type = 0b00111001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F859B0>

# %%
# Rule 139
# 1 1 0 0   0 1 0 1
#
#   6     o
# 4     o
#   2     3
# o     o
#
rule_type = 0b11000101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F855F8>

# %%
# Rule 140
# 1 0 1 0   0 1 0 1
#
#   6     o
# 4     o
#   o     3
# o     1
#
rule_type = 0b10100101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F85BA8>

# %%
# Rule 141
# 0 1 1 0   0 1 0 1
#
#   6     o
# 4     o
#   o     3
# 0     o
#
rule_type = 0b01100101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F7C208>

# %%
# Rule 142
# 1 0 0 1   0 1 0 1
#
#   6     o
# 4     o
#   2     o
# o     1
#
rule_type = 0b10010101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F41357518>

# %%
# Rule 143
# 0 1 0 1   0 1 0 1
#
#   6     o
# 4     o
#   2     o
# 0     o
#
rule_type = 0b01010101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F41357940>

# %%
# Rule 144
# 1 1 0 0   1 0 1 0
#
#   o     7
# o     5
#   2     3
# o     o
#
rule_type = 0b00110101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F7C5F8>

# %%
# Rule 145
# 1 0 0 0   1 1 0 1
#
#   6     o
# o     o
#   2     3
# o     1
#
rule_type = 0b10001101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F4135B080>

# %%
# Rule 146
# 0 1 0 0   1 1 0 1
#
#   6     o
# o     o
#   2     3
# 0     o
#
rule_type = 0b01001101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F7CEF0>

# %%
# Rule 147
# 0 0 1 0   1 1 0 1
#
#   6     o
# o     o
#   o     3
# 0     1
#
rule_type = 0b00101101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F40F7C9B0>

# %%
# Rule 148
# 0 0 0 1   1 1 0 1
#
#   6     o
# o     o
#   2     o
# 0     1
#
rule_type = 0b00011101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F41379828>

# %%
# Rule 149
# 1 1 0 0   0 0 1 1
#
#   o     o
# 4     5
#   2     3
# o     o
#
rule_type = 0b11000011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F4135BB70>

# %%
# Rule 150
# 1 0 1 0   0 0 1 1
#
#   o     o
# 4     5
#   o     3
# o     1
#
rule_type = 0b10100011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8F41379940>
