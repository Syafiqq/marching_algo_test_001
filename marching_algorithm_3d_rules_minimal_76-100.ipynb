# %%
import numpy as np
import pyvista as pv
import marching_3d_rules_minimal as rules

# %%
points = np.array(
    [
        [10, 10, 10],
        [20, 10, 10],
        [10, 20, 10],
        [20, 20, 10],
        [10, 10, 20],
        [20, 10, 20],
        [10, 20, 20],
        [20, 20, 20],
    ]
    , dtype=np.float)
points
# Out:
# array([[10., 10., 10.],
#        [20., 10., 10.],
#        [10., 20., 10.],
#        [20., 20., 10.],
#        [10., 10., 20.],
#        [20., 10., 20.],
#        [10., 20., 20.],
#        [20., 20., 20.]])

# %%
def plot_data(cloud_points, faces):
    cloud = pv.PolyData(cloud_points, faces=faces)
    plot = pv.Plotter()
    plot.add_points(points)
    plot.add_mesh(cloud, show_edges=True, edge_color='r')
    plot.show_bounds()
    plot.show_grid()
    plot.show()

# %%
# Rule 76
# 1 0 0 1   0 0 0 1
#
#   6     o
# 4     5
#   2     o
# o     1
#
rule_type = 0b10010001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# /Users/engineering/Documents/anaconda3/envs/shapely-pyvista/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880A5CB00>

# %%
# Rule 76 (v2)
# 1 0 0 1   0 0 0 1
#
#   6     o
# 4     5
#   2     o
# o     1
#
rule_type = 0b10010001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B02908>

# %%
# Rule 77
# 0 1 0 1   0 0 0 1
#
#   6     o
# 4     5
#   2     o
# 0     o
#
rule_type = 0b01010001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9890D45DD8>

# %%
# Rule 78
# 0 0 1 1   0 0 0 1
#
#   6     o
# 4     5
#   o     o
# 0     1
#
rule_type = 0b00110001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B02B70>

# %%
# Rule 79
# 1 0 0 0   1 0 0 1
#
#   6     o
# o     5
#   2     3
# o     1
#
rule_type = 0b10001001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0AC18>

# %%
# Rule 79 (v2)
# 1 0 0 0   1 0 0 1
#
#   6     o
# o     5
#   2     3
# o     1
#
rule_type = 0b10001001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0FB38>

# %%
# Rule 80
# 0 1 0 0   1 0 0 1
#
#   6     o
# o     5
#   2     3
# 0     o
#
rule_type = 0b01001001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0ACC0>

# %%
# Rule 80 (v2)
# 0 1 0 0   1 0 0 1
#
#   6     o
# o     5
#   2     3
# 0     o
#
rule_type = 0b01001001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0AC88>

# %%
# Rule 81
# 0 0 1 0   1 0 0 1
#
#   6     o
# o     5
#   o     3
# 0     1
#
rule_type = 0b00101001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0A358>

# %%
# Rule 81 (v2)
# 0 0 1 0   1 0 0 1
#
#   6     o
# o     5
#   o     3
# 0     1
#
rule_type = 0b00101001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B3A048>

# %%
# Rule 82
# 0 0 0 1   1 0 0 1
#
#   6     o
# o     5
#   2     o
# 0     1
#
rule_type = 0b00011001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B37B70>

# %%
# Rule 82 (v2)
# 0 0 0 1   1 0 0 1
#
#   6     o
# o     5
#   2     o
# 0     1
#
rule_type = 0b00011001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B374A8>

# %%
# Rule 83
# 1 0 0 0   0 1 0 1
#
#   6     o
# 4     o
#   2     3
# o     1
#
rule_type = 0b10000101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B0A4A8>

# %%
# Rule 83 (v2)
# 1 0 0 0   0 1 0 1
#
#   6     o
# 4     o
#   2     3
# o     1
#
rule_type = 0b10000101
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880E9B320>

# %%
# Rule 84
# 0 1 0 0   0 1 0 1
#
#   6     o
# 4     o
#   2     3
# 0     o
#
rule_type = 0b01000101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880E92438>

# %%
# Rule 85
# 0 0 1 0   0 1 0 1
#
#   6     o
# 4     o
#   o     3
# 0     1
#
rule_type = 0b00100101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B3BD68>

# %%
# Rule 85 (v2)
# 0 0 1 0   0 1 0 1
#
#   6     o
# 4     o
#   o     3
# 0     1
#
rule_type = 0b00100101
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EB3860>

# %%
# Rule 86
# 0 0 0 1   0 1 0 1
#
#   6     o
# 4     o
#   2     o
# 0     1
#
rule_type = 0b00010101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98B00E3FD0>

# %%
# Rule 87
# 0 0 0 0   1 1 0 1
#
#   6     o
# o     o
#   2     3
# 0     1
#
rule_type = 0b00001101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880E9B860>

# %%
# Rule 88
# 1 0 0 0   0 0 1 1
#
#   o     o
# 4     5
#   2     3
# o     1
#
rule_type = 0b10000011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B028D0>

# %%
# Rule 88 (v2)
# 1 0 0 0   0 0 1 1
#
#   o     o
# 4     5
#   2     3
# o     1
#
rule_type = 0b10000011
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EAEA20>

# %%
# Rule 89
# 0 1 0 0   0 0 1 1
#
#   o     o
# 4     5
#   2     3
# 0     o
#
rule_type = 0b01000011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B37DD8>

# %%
# Rule 89 (v2)
# 0 1 0 0   0 0 1 1
#
#   o     o
# 4     5
#   2     3
# 0     o
#
rule_type = 0b01000011
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EAEDA0>

# %%
# Rule 90
# 0 0 1 0   0 0 1 1
#
#   o     o
# 4     5
#   o     3
# 0     1
#
rule_type = 0b00100011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880E9BE10>

# %%
# Rule 91
# 0 0 0 1   0 0 1 1
#
#   o     o
# 4     5
#   2     o
# 0     1
#
rule_type = 0b00010011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EAE7F0>

# %%
# Rule 92
# 0 0 0 0   1 0 1 1
#
#   o     o
# o     5
#   2     3
# 0     1
#
rule_type = 0b00001011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98911334A8>

# %%
# Rule 93
# 0 0 0 0   0 1 1 1
#
#   o     o
# 4     o
#   2     3
# 0     1
#
rule_type = 0b00000111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880E92160>

# %%
# Rule 94
# 1 1 1 1   0 0 0 0
#
#   6     7
# 4     5
#   o     o
# o     o
#
rule_type = 0b11110000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98A0B37C88>

# %%
# Rule 95
# 1 1 1 0   1 0 0 0
#
#   6     7
# o     5
#   o     3
# o     o
#
rule_type = 0b11101000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EAE7F0>

# %%
# Rule 96
# 1 1 0 1   1 0 0 0
#
#   6     7
# o     5
#   2     o
# o     o
#
rule_type = 0b11011000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98911335C0>

# %%
# Rule 97
# 1 0 1 1   1 0 0 0
#
#   6     7
# o     5
#   o     o
# o     1
#
rule_type = 0b10111000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9880EAE0F0>

# %%
# Rule 98
# 0 1 1 1   1 0 0 0
#
#   6     7
# o     5
#   o     o
# 0     o
#
rule_type = 0b01111000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9891133048>

# %%
# Rule 98 (v2)
# 0 1 1 1   1 0 0 0
#
#   6     7
# o     5
#   o     o
# 0     o
#
rule_type = 0b01111000
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9891154080>

# %%
# Rule 99
# 1 1 1 0   0 1 0 0
#
#   6     7
# 4     o
#   o     3
# o     o
#
rule_type = 0b11100100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9891154240>

# %%
# Rule 100
# 1 1 0 1   0 1 0 0
#
#   6     7
# 4     o
#   2     o
# o     o
#
rule_type = 0b11010100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9891133FD0>
