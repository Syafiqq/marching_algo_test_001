# %%
import numpy as np
import pyvista as pv
import marching_3d_rules_minimal as rules

# %%
points = np.array(
    [
        [10, 10, 10],
        [20, 10, 10],
        [10, 20, 10],
        [20, 20, 10],
        [10, 10, 20],
        [20, 10, 20],
        [10, 20, 20],
        [20, 20, 20],
    ]
    , dtype=np.float)
points
# Out:
# array([[10., 10., 10.],
#        [20., 10., 10.],
#        [10., 20., 10.],
#        [20., 20., 10.],
#        [10., 10., 20.],
#        [20., 10., 20.],
#        [10., 20., 20.],
#        [20., 20., 20.]])

# %%
def plot_data(cloud_points, faces):
    cloud = pv.PolyData(cloud_points, faces=faces)
    plot = pv.Plotter()
    plot.add_points(points)
    plot.add_mesh(cloud, show_edges=True, edge_color='r')
    plot.show_bounds()
    plot.show_grid()
    plot.camera_position = 'yz'
    plot.camera.azimuth = -45.0
    plot.camera.elevation = 30.0
    plot.show()

# %%
# Rule 226
# 0 1 1 1   1 1 1 0
#
#   o     7
# o     o
#   o     o
# 0     o
#
rule_type = 0b01111110
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# /Users/engineering/Documents/anaconda3/envs/shapely-pyvista/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28205E80>

# %%
# Rule 227
# 1 1 1 1   1 0 0 1
#
#   6     o
# o     5
#   o     o
# o     o
#
rule_type = 0b11111001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD58775898>

# %%
# Rule 228
# 1 1 1 1   0 1 0 1
#
#   6     o
# 4     o
#   o     o
# o     o
#
rule_type = 0b11110101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD281E3A20>

# %%
# Rule 229
# 1 1 1 0   1 1 0 1
#
#   6     o
# o     o
#   o     3
# o     o
#
rule_type = 0b11101101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD58775BE0>

# %%
# Rule 230
# 1 1 0 1   1 1 0 1
#
#   6     o
# o     o
#   2     o
# o     o
#
rule_type = 0b11011101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD58775940>

# %%
# Rule 231
# 1 0 1 1   1 1 0 1
#
#   6     o
# o     o
#   o     o
# o     1
#
rule_type = 0b10111101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48447630>

# %%
# Rule 232
# 0 1 1 1   1 1 0 1
#
#   6     o
# o     o
#   o     o
# 0     o
#
rule_type = 0b01111101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48447A20>

# %%
# Rule 233
# 1 1 1 1   0 0 1 1
#
#   o     o
# 4     5
#   o     o
# o     o
#
rule_type = 0b11110011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48455B70>

# %%
# Rule 234
# 1 1 1 0   1 0 1 1
#
#   o     o
# o     5
#   o     3
# o     o
#
rule_type = 0b11101011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48453AC8>

# %%
# Rule 235
# 1 1 0 1   1 0 1 1
#
#   o     o
# o     4
#   2     o
# o     o
#
rule_type = 0b11011011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48453B70>

# %%
# Rule 236
# 1 0 1 1   1 0 1 1
#
#   o     o
# o     5
#   o     o
# o     1
#
rule_type = 0b10111011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48460048>

# %%
# Rule 237
# 0 1 1 1   1 0 1 1
#
#   o     o
# o     5
#   o     o
# 0     o
#
rule_type = 0b01111011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48460DD8>

# %%
# Rule 238
# 1 1 1 0   0 1 1 1
#
#   o     o
# 4     o
#   o     3
# o     o
#
rule_type = 0b11100111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD484609E8>

# %%
# Rule 239
# 1 1 0 1   0 1 1 1
#
#   o     o
# 4     o
#   2     o
# o     o
#
rule_type = 0b11010111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48447550>

# %%
# Rule 240
# 1 0 1 1   0 1 1 1
#
#   o     o
# 4     o
#   o     o
# o     1
#
rule_type = 0b10110111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48453630>

# %%
# Rule 241
# 0 1 1 1   0 1 1 1
#
#   o     o
# 4     o
#   o     o
# 0     o
#
rule_type = 0b01110111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD1A16CF60>

# %%
# Rule 242
# 1 1 0 0   1 1 1 1
#
#   o     o
# o     o
#   2     3
# o     o
#
rule_type = 0b11001111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48455748>

# %%
# Rule 243
# 1 0 1 0   1 1 1 1
#
#   o     o
# o     o
#   o     3
# o     1
#
rule_type = 0b10101111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD1A17C630>

# %%
# Rule 244
# 0 1 1 0   1 1 1 1
#
#   o     o
# o     o
#   o     3
# 0     o
#
rule_type = 0b01101111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD58775400>

# %%
# Rule 245
# 1 0 0 1   1 1 1 1
#
#   o     o
# o     o
#   2     o
# o     1
#
rule_type = 0b10011111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD1A186128>

# %%
# Rule 246
# 0 1 0 1   1 1 1 1
#
#   o     o
# o     o
#   2     o
# 0     o
#rule_type = 0b01011111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD1A16C940>

# %%
# Rule 247
# 0 0 1 1   1 1 1 1
#
#   o     o
# o     o
#   o     o
# 0     1
#
rule_type = 0b00111111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD4842B860>

# %%
# Rule 248
# 1 1 1 1   1 1 1 0
#
#   o     7
# o     o
#   o     o
# o     o
#
rule_type = 0b11111110
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48453D30>

# %%
# Rule 249
# 1 1 1 1   1 1 0 1
#
#   6     o
# o     o
#   o     o
# o     o
#
rule_type = 0b11111101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD1A16C8D0>

# %%
# Rule 250
# 1 1 1 1   1 0 1 1
#
#   o     o
# o     5
#   o     o
# o     o
#
rule_type = 0b11111011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28E880B8>

# %%
# Rule 251
# 1 1 1 1   0 1 1 1
#
#   o     o
# 4     o
#   o     o
# o     o
#
rule_type = 0b11110111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28E88B70>

# %%
# Rule 252
# 1 1 1 0   1 1 1 1
#
#   o     o
# o     o
#   o     3
# o     o
#
rule_type = 0b11101111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD48460470>

# %%
# Rule 253
# 1 1 0 1   1 1 1 1
#
#   o     o
# o     o
#   2     o
# o     o
#
rule_type = 0b11011111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28E88E48>

# %%
# Rule 254
# 1 0 1 1   1 1 1 1
#
#   o     o
# o     o
#   o     o
# o     1
#
rule_type = 0b10111111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28E945C0>

# %%
# 0 1 1 1   1 1 1 1
#
#   o     o
# o     o
#   o     o
# 0     o
#
rule_type = 0b01111111
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCD28E94A90>

# %%
rule_type = 0b11111111

# 0 1 1 1   1 1 1 1
#
#   o     o
# o     o
#   o     o
# o     o

# Empty
