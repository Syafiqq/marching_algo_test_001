# %%
import numpy as np
import pyvista as pv
import marching_3d_rules_minimal as rules

# %%
points = np.array(
    [
        [10, 10, 10],
        [20, 10, 10],
        [10, 20, 10],
        [20, 20, 10],
        [10, 10, 20],
        [20, 10, 20],
        [10, 20, 20],
        [20, 20, 20],
    ]
    , dtype=np.float)
points
# Out:
# array([[10., 10., 10.],
#        [20., 10., 10.],
#        [10., 20., 10.],
#        [20., 20., 10.],
#        [10., 10., 20.],
#        [20., 10., 20.],
#        [10., 20., 20.],
#        [20., 20., 20.]])

# %%
def plot_data(cloud_points, faces):
    cloud = pv.PolyData(cloud_points, faces=faces)
    plot = pv.Plotter()
    plot.add_points(points)
    plot.add_mesh(cloud, show_edges=True, edge_color='r')
    plot.show_bounds()
    plot.show_grid()
    plot.show()

# %%
# Rule 26
# 0 1 0 0 0 0 1 0
#
#   o     7
# 4     5
#   2     3
# 0     o
#
rule_type = 0b01000010
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# /Users/engineering/Documents/anaconda3/envs/shapely-pyvista/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0905B70>

# %%
# Rule 27
# 0 0 1 0 0 0 1 0
#
#   o     7
# 4     5
#   o      3
# 0     1
#
rule_type = 0b00100010
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83E0BCCA20>

# %%
# Rule 28
# 0 0 0 1 0 0 1 0
#
#   o     7
# 4     5
#   2     o
# 0     1
#
rule_type = 0b00010010
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A1DA20>

# %%
# Rule 28 (v2)
# 0 0 0 1 0 0 1 0
#
#   o     7
# 4     5
#   2     o
# 0     1
#
rule_type = 0b00010010
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83E0BCC940>

# %%
# Rule 29
# 0 0 0 0 1 0 1 0
#
#   o     7
# o     5
#   2     3
# 0     1
#
rule_type = 0b00001010
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A1F668>

# %%
# Rule 30
# 0 0 0 0 0 1 1 0
#
#   o     7
# 4     o
#   2     3
# 0     1
#
rule_type = 0b00000110
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0477828>

# %%
# Rule 30 (v2)
# 0 0 0 0 0 1 1 0
#
#   o     7
# 4     o
#   2     3
# 0     1
#
rule_type = 0b00000110
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A1F278>

# %%
# Rule 31
# 1 0 0 0 0 0 0 1
#
#   6     o
# 4     5
#   2     3
# o     1
#
rule_type = 0b10000001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83E0BCCAC8>

# %%
# Rule 32
# 0 1 0 0 0 0 0 1
#
#   6     o
# 4     5
#   2     3
# 0     o
#
rule_type = 0b01000001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A45CF8>

# %%
# Rule 32 (v2)
# 0 1 0 0 0 0 0 1
#
#   6     o
# 4     5
#   2     3
# 0     o
#
rule_type = 0b01000001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A45630>

# %%
# Rule 33
# 0 0 1 0 0 0 0 1
#
#   6     o
# 4     5
#   o     3
# 0     1
#
rule_type = 0b00100001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A1FA20>

# %%
# Rule 33 (v2)
# 0 0 1 0 0 0 0 1
#
#   6     o
# 4     5
#   o     3
# 0     1
#
rule_type = 0b00100001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A41FD0>

# %%
# Rule 34
# 0 0 0 0 0 0 0 1
#
#   6     o
# 4     5
#   2     o
# 0     1
#
rule_type = 0b00010001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A41C88>

# %%
# Rule 35
# 0 0 0 0 1 0 0 1
#
#   6     o
# o     5
#   2     3
# 0     1
#
rule_type = 0b00001001
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A35D30>

# %%
# Rule 35 (v2)
# 0 0 0 0 1 0 0 1
#
#   6     o
# o     5
#   2     3
# 0     1
#
rule_type = 0b00001001
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C051A6A0>

# %%
# Rule 36
# 0 0 0 0 0 1 0 1
#
#   6     o
# 4     o
#   2     3
# 0     1
#
rule_type = 0b00000101
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A35E48>

# %%
# Rule 37
# 0 0 0 0 0 0 1 1
#
#   o     o
# 4     5
#   2     3
# 0     1
#
rule_type = 0b00000011
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C0525DA0>

# %%
# Rule 38
# 1 1 1 0 0 0 0 0
#
#   6     7
# 4      5
#   o     3
# o     o
#
rule_type = 0b11100000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C0520D30>

# %%
# Rule 39
# 1 1 0 1 0 0 0 0
#
#   6     7
# 4     5
#   2     o
# o     o
#
rule_type = 0b11010000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C0520908>

# %%
# Rule 40
# 1 0 1 1 0 0 0 0
#
#   6     7
# 4     5
#   o     o
# o     1
#
rule_type = 0b10110000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A35400>

# %%
# Rule 41
# 0 1 1 1 0 0 0 0
#
#   6     7
# 4     5
#   o     o
# 0     o
#
rule_type = 0b01110000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052C6A0>

# %%
# Rule 42
# 1 1 0 0 1 0 0 0
#
#   6     7
# o     5
#   2     3
# o     o
#
rule_type = 0b11001000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052CC88>

# %%
# Rule 43
# 1 0 1 0 1 0 0 0
#
#   6     7
# o     5
#   o     3
# o     1
#
rule_type = 0b10101000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052C630>

# %%
# Rule 44
# 0 1 1 0 1 0 0 0
#
#   6     7
# o     5
#   o     3
# 0     o
#
rule_type = 0b01101000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C051ABE0>

# %%
# Rule 44 (v2)
# 0 1 1 0 1 0 0 0
#
#   6     7
# o     5
#   o     3
# 0     o
#
rule_type = 0b01101000
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052C710>

# %%
# Rule 45
# 1 0 0 1 1 0 0 0
#
#   6     7
# o     5
#   2     o
# o     1
#
rule_type = 0b10011000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C053D9E8>

# %%
# Rule 45 (v2)
# 1 0 0 1 1 0 0 0
#
#   6     7
# o     5
#   2     o
# o     1
#
rule_type = 0b10011000
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C051A400>

# %%
# Rule 46
# 0 1 0 1 1 0 0 0
#
#   6     7
# o     5
#   2     o
# 0     o
#
rule_type = 0b01011000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052CF28>

# %%
# Rule 46 (v2)
# 0 1 0 1 1 0 0 0
#
#   6     7
# o     5
#   2     o
# 0     o
#
rule_type = 0b01011000
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C052CDD8>

# %%
# Rule 47
# 0 0 1 1 1 0 0 0
#
#   6     7
# o     5
#   o     o
# 0     1
#
rule_type = 0b00111000
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C053DBE0>

# %%
# Rule 47 (v2)
# 0 0 1 1 1 0 0 0
#
#   6     7
# o     5
#   o     o
# 0     1
#
rule_type = 0b00111000
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83E0BCC358>

# %%
# Rule 48
# 1 1 0 0 0 1 0 0
#
#   6     7
# 4     o
#   2     3
# o     o
#
rule_type = 0b11000100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B0A35EB8>

# %%
# Rule 49
# 1 0 1 0 0 1 0 0
#
#   6     7
# 4     o
#   o     3
# o     1
#
rule_type = 0b10100100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B13C39B0>

# %%
# Rule 49 (v2)
# 1 0 1 0 0 1 0 0
#
#   6     7
# 4     o
#   o     3
# o     1
#
rule_type = 0b10100100
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B13C3F60>

# %%
# Rule 50
# 0 1 1 0 0 1 0 0
#
#   6     7
# 4     o
#   o     3
# 0     o
#
rule_type = 0b01100100
points_r = rules.to_points(points, rule_type)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83B13C3F60>

# %%
# Rule 50 (v2)
# 0 1 1 0 0 1 0 0
#
#   6     7
# 4     o
#   o     3
# 0     o
#
rule_type = 0b01100100
variant = 2
points_r = rules.to_points(points, rule_type, variant=variant)
faces_r = rules.to_faces(np.arange(0, len(points_r), 1), rule_type, variant=variant)

plot_data(points_r, faces=faces_r)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F83C053DFD0>
