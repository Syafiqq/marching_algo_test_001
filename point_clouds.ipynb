# %%
import numpy as np
import pyvista as pv


points = np.random.random((10, 2))
points
# Out:
# array([[0.44357458, 0.63534319],
#        [0.65060379, 0.36065721],
#        [0.81823534, 0.7969989 ],
#        [0.91906792, 0.20605272],
#        [0.73961396, 0.1945016 ],
#        [0.86797123, 0.7566444 ],
#        [0.51493346, 0.03093755],
#        [0.7206538 , 0.17168747],
#        [0.91566103, 0.0830595 ],
#        [0.57347568, 0.42308202]])

# %%
points = np.pad(points, [(0, 0), (0, 1)], mode='constant', constant_values=0)
points
# Out:
# array([[0.44357458, 0.63534319, 0.        ],
#        [0.65060379, 0.36065721, 0.        ],
#        [0.81823534, 0.7969989 , 0.        ],
#        [0.91906792, 0.20605272, 0.        ],
#        [0.73961396, 0.1945016 , 0.        ],
#        [0.86797123, 0.7566444 , 0.        ],
#        [0.51493346, 0.03093755, 0.        ],
#        [0.7206538 , 0.17168747, 0.        ],
#        [0.91566103, 0.0830595 , 0.        ],
#        [0.57347568, 0.42308202, 0.        ]])

# %%
cloud = pv.PolyData(points)

pv.plot(cloud, show_bounds=True, cpos='xy')
# Out:
# /Users/engineering/Documents/anaconda3/envs/shapely-pyvista/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9422536DA0>
